# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Learning Projects/Survey Dataset - Technical Interview.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %%
df.shape
# Out:
# (6867, 14)

# %%
df.nunique()
# Out:
# response_id         6867
# collection_date        9
# urban_rural            2
# education              7
# income                 8
# Vote_Now              18
# Past_Vote             14
# CM_satisfaction        5
# MLA_satisfaction       5
# age                   60
# gender                 3
# assembly_no          241
# category               5
# weight              1561
# dtype: int64

# %%
#How many samples were collected on each day?
df['collection_date'].unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
df['collection_date'].nunique()
# Out:
# 9

# %%
df['collection_date'].value_counts(ascending=True)
# Out:
# 5-31-2017     557
# 5-30-2017     582
# 5-26-2017     598
# 6-1-2017      607
# 5-29-2017     620
# 5-27-2017     665
# 5-28-2017     761
# 5-25-2017     998
# 5-24-2017    1479
# Name: collection_date, dtype: int64

# %%
#What proportion of the total respondents were aged less than 45?
df.age.dtypes
# Out:
# dtype('O')

# %%
df.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
df.age.value_counts()
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
df.age.replace({'24ko':'24'},inplace=True)

# %%
df.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
df.age = df.age.astype(int)

# %%
df.age.dtypes
# Out:
# dtype('int64')

# %%
df[df.age<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
6399/6867 *100
# Out:
# 93.18479685452162

# %%
#Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to.
#The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after the column creation

# %%
df1 = df.copy()
df1
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
df1.insert(10, 'age_group', df.age)

# %%
df1.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#    age_group gender  assembly_no category    weight
# ...

# %%
df2 = df1[(df1.age_group >= 18) & (df1.age_group < 25)]

# %%
df2.head()
# Out:
#     response_id collection_date urban_rural          education  \
# 4             5       5-24-2017       Rural           Graduate
# 8             9       5-24-2017       Urban          12th Pass
# 14           15       5-24-2017       Rural           Graduate
# 16           17       5-24-2017       Rural  Post - Graduation
# 18           19       5-24-2017       Rural           Graduate
#
#                  income Vote_Now     Past_Vote        CM_satisfaction  \
# 4   ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8     BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14   ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16    BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18  ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
#
#       MLA_satisfaction  age  age_group gender  assembly_no category    weight
# 4      Fully Satisfied   22         22   Male          176       BC  0.333505
# ...

# %%
df2.age_group.unique()
# Out:
# array([22, 23, 24, 19, 21, 18, 20])

# %%
df2.age_group = '18-25'
# Out:
# <ipython-input-26-aa7943c6e561>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.age_group = '18-25'

# %%
df3 = df1[(df1.age_group >= 25)&(df1.age_group < 40)]

# %%
df3.age_group.unique()
# Out:
# array([26, 34, 25, 36, 38, 29, 30, 39, 37, 32, 27, 28, 35, 31, 33])

# %%
df3.age_group = '25-40'
# Out:
# <ipython-input-29-2a886594a103>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.age_group = '25-40'

# %%
df4 = df1[(df1.age_group >= 40)&(df1.age_group < 55)]

# %%
df4.age_group.unique()
# Out:
# array([42, 51, 44, 53, 48, 45, 40, 49, 46, 43, 41, 50, 54, 47, 52])

# %%
df4.age_group = '40-55'
# Out:
# <ipython-input-32-8af1872f8d29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.age_group = '40-55'

# %%
df5 = df1[df1.age_group >= 55]

# %%
df5.age_group.unique()
# Out:
# array([74, 70, 58, 56, 55, 62, 60, 59, 61, 66, 57, 67, 65, 71, 63, 64, 68,
#        69, 99, 72, 75, 76])

# %%
df5.age_group = '55+'
# Out:
# <ipython-input-35-ab0782bf5b77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.age_group = '55+'

# %%
df1 = pd.concat([df2,df3,df4,df5])

# %%
df1.tail()
# Out:
#       response_id collection_date urban_rural               education  \
# 6649         6650       5-30-2017       Urban                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income    Vote_Now Past_Vote        CM_satisfaction  \
# 6649  ₹ 30,000 - ₹ 50,000  Left Front       INC  Somewhat Dissatisfied
# 6702  ₹ 10,000 - ₹ 20,000         BJP       BJP  Somewhat Dissatisfied
# 6720  ₹ 10,000 - ₹ 20,000         BJP       BJP     Somewhat Satisfied
# 6787  ₹ 20,000 - ₹ 30,000       JD(U)       BJP        Fully Satisfied
# 6851  ₹ 30,000 - ₹ 50,000         BJP       BJP        Fully Satisfied
#
#            MLA_satisfaction  age age_group gender  assembly_no category  \
# ...

# %%
#How many samples were collected for each age-group? Which age-group had the most samples?
df1.age_group.value_counts()
# Out:
# 25-40    3844
# 18-25    2094
# 40-55     801
# 55+       128
# Name: age_group, dtype: int64

# %%
#What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?
df[(df['Vote_Now'] == 'RJD') & (df['Past_Vote'] == 'RJD')]
# Out:
#       response_id collection_date urban_rural          education  \
# 3               4       5-24-2017       Urban           Graduate
# 9              10       5-24-2017       Urban          12th Pass
# 16             17       5-24-2017       Rural  Post - Graduation
# 19             20       5-24-2017       Rural           Graduate
# 21             22       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6846         6847        6-1-2017       Rural  Post - Graduation
# 6848         6849        6-1-2017       Rural  Post - Graduation
# 6858         6859        6-1-2017       Rural           Graduate
# 6860         6861        6-1-2017       Rural           Graduate
# 6863         6864        6-1-2017       Rural           Graduate
#
#                    income Vote_Now Past_Vote     CM_satisfaction  \
# 3     ₹ 10,000 - ₹ 20,000      RJD       RJD  Fully Dissatisfied
# ...

# %%
811/6867 *100
# Out:
# 11.810106305519149

# %%
#For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM.
#So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3.

# %%
CM = df[df['CM_satisfaction'] == 'Fully Satisfied']

# %%
a = CM['collection_date'].value_counts()
a
# Out:
# 5-24-2017    146
# 5-25-2017     95
# 5-28-2017     92
# 6-1-2017      75
# 5-29-2017     73
# 5-30-2017     65
# 5-31-2017     62
# 5-26-2017     59
# 5-27-2017     54
# Name: collection_date, dtype: int64

# %%
b = df['collection_date'].value_counts()
b
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
c = a/b *100
c
# Out:
# 5-24-2017     9.871535
# 5-25-2017     9.519038
# 5-26-2017     9.866221
# 5-27-2017     8.120301
# 5-28-2017    12.089356
# 5-29-2017    11.774194
# 5-30-2017    11.168385
# 5-31-2017    11.131059
# 6-1-2017     12.355848
# Name: collection_date, dtype: float64

# %%
# In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA.
# Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
MLA = df[df['MLA_satisfaction'] == 'Fully Dissatisfied']

# %%
a1 = MLA['collection_date'].value_counts()
a1
# Out:
# 5-24-2017    887
# 5-25-2017    630
# 5-28-2017    462
# 5-27-2017    403
# 6-1-2017     385
# 5-30-2017    361
# 5-26-2017    353
# 5-29-2017    350
# 5-31-2017    321
# Name: collection_date, dtype: int64

# %%
b1 = df['collection_date'].value_counts()
b1
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
c1 = a1/b1 * 100
c1
# Out:
# 5-24-2017    59.972955
# 5-25-2017    63.126253
# 5-26-2017    59.030100
# 5-27-2017    60.601504
# 5-28-2017    60.709593
# 5-29-2017    56.451613
# 5-30-2017    62.027491
# 5-31-2017    57.630162
# 6-1-2017     63.426689
# Name: collection_date, dtype: float64

# %%
type(c1)
# Out:
# pandas.core.series.Series

# %%
d = pd.DataFrame(c1)
d
# Out:
#            collection_date
# 5-24-2017        59.972955
# 5-25-2017        63.126253
# 5-26-2017        59.030100
# 5-27-2017        60.601504
# 5-28-2017        60.709593
# 5-29-2017        56.451613
# 5-30-2017        62.027491
# 5-31-2017        57.630162
# 6-1-2017         63.426689

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
d.collection_date.plot(kind = 'line', figsize = (10,5))
# Out:
# <Axes: >

# %%
# Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.
df.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', aggfunc = 'count')
# Out:
#              CM_satisfaction                                              \
# Vote_Now                 AAP AIMIM     BJP  BSP  HAM   INC JAP(L)  JD(U)
# Past_Vote
# BJP                      7.0   1.0  1630.0  3.0  5.0  42.0  101.0  110.0
# BSP                      NaN   1.0     2.0  5.0  NaN   1.0    NaN    NaN
# Did not vote             8.0   5.0   231.0  2.0  1.0  22.0   41.0   69.0
# HAM                      2.0   NaN    25.0  NaN  1.0   NaN    3.0    2.0
# INC                      NaN   6.0     6.0  NaN  NaN  57.0   10.0    9.0
# JAP(L)                   NaN   NaN     4.0  NaN  NaN   NaN   35.0    NaN
# JD(U)                    6.0  10.0   254.0  2.0  2.0  45.0   72.0  279.0
# LJP                      NaN   NaN    76.0  1.0  NaN   4.0    3.0    6.0
# Left Front               NaN   1.0     2.0  NaN  NaN   1.0    NaN    NaN
# NOTA                     NaN   1.0    29.0  1.0  NaN   9.0    7.0    7.0
# Others                   1.0   5.0    45.0  1.0  1.0   4.0    7.0    4.0
# ...

# %%
#  Repeat the above question with the cell values as the sum of “weight”.
df.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'weight', aggfunc = 'sum')
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %%
 # Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group.

# %%
df1.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data1 = df1.groupby('age_group').count()
data1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             2094             2094         2094       2094    2094
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          2094       2094             2094              2094  2094
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        2094         2094      2094    2094
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
#Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.
data2 = df1[df1['Vote_Now'] == 'JD(U)']

# %%
data3 = data2.groupby('age_group').count()
data3
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              181              181          181        181     181
# 25-40              264              264          264        264     264
# 40-55               68               68           68         68      68
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           181        181              181               181  181
# 25-40           264        264              264               264  264
# 40-55            68         68               68                68   68
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         181          181       181     181
# 25-40         264          264       264     264
# 40-55          68           68        68      68
# ...

# %%
# Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.

# %%
data1
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25             2094             2094         2094       2094    2094
# 25-40             3844             3844         3844       3844    3844
# 40-55              801              801          801        801     801
# 55+                128              128          128        128     128
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction   age  \
# age_group
# 18-25          2094       2094             2094              2094  2094
# 25-40          3844       3844             3844              3844  3844
# 40-55           801        801              801               801   801
# 55+             128        128              128               128   128
#
#            gender  assembly_no  category  weight
# age_group
# 18-25        2094         2094      2094    2094
# 25-40        3844         3844      3844    3844
# 40-55         801          801       801     801
# ...

# %%
data3
# Out:
#            response_id  collection_date  urban_rural  education  income  \
# age_group
# 18-25              181              181          181        181     181
# 25-40              264              264          264        264     264
# 40-55               68               68           68         68      68
# 55+                 13               13           13         13      13
#
#            Vote_Now  Past_Vote  CM_satisfaction  MLA_satisfaction  age  \
# age_group
# 18-25           181        181              181               181  181
# 25-40           264        264              264               264  264
# 40-55            68         68               68                68   68
# 55+              13         13               13                13   13
#
#            gender  assembly_no  category  weight
# age_group
# 18-25         181          181       181     181
# 25-40         264          264       264     264
# 40-55          68           68        68      68
# ...

# %%
pd.merge(data1, data3, on = 'age_group')
# Out:
#            response_id_x  collection_date_x  urban_rural_x  education_x  \
# age_group
# 18-25               2094               2094           2094         2094
# 25-40               3844               3844           3844         3844
# 40-55                801                801            801          801
# 55+                  128                128            128          128
#
#            income_x  Vote_Now_x  Past_Vote_x  CM_satisfaction_x  \
# age_group
# 18-25          2094        2094         2094               2094
# 25-40          3844        3844         3844               3844
# 40-55           801         801          801                801
# 55+             128         128          128                128
#
#            MLA_satisfaction_x  age_x  ...  income_y  Vote_Now_y  Past_Vote_y  \
# age_group                             ...
# 18-25                    2094   2094  ...       181         181          181
# ...
